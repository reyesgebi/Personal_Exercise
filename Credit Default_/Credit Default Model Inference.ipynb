# %%
import pandas as pd
import numpy as np
import json
import joblib

# %%
# Open Files

with open('random.pkl', 'rb') as file_1 :
    random_for = joblib.load(file_1)

# %%
random_for
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('outlier',
#                                                                    Winsorizer(fold=1.5,
#                                                                               tail='both')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Interest_rate_spread',
#                                                    'rate_of_interest',
#                                                    'dtir1']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['credit_type']),
# ...

# %%
# Creating new DataFrame for the Model Inference
df = pd.DataFrame({
    'loan_purpose': ['p1','p2','p4'], 
    'Credit_Worthiness': ['l1','l1','l1'], 
    'open_credit': ['nopc','nopc','nopc'], 
    'business_or_commercial': ['b/c','nob/c','nob/c'], 
    'loan_amount': [116450,222309,432874], 
    'Upfront_charges': [590,263,148],
    'credit_type': ['EXP','EQUI','EQUI'], 
    'Interest_rate_spread': [0.21,0.124,0.549], 
    'rate_of_interest': [5,4.689,6.1], 
    'dtir1': [46,30,25],
    'lump_sum_payment': ['lpsm','not_lpsm','lpsm']
})
df
# Out:
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                    b/c
# 1           p2                l1        nopc                  nob/c
# 2           p4                l1        nopc                  nob/c
#
#    loan_amount  Upfront_charges credit_type  Interest_rate_spread  \
# 0       116450              590         EXP                 0.210
# 1       222309              263        EQUI                 0.124
# 2       432874              148        EQUI                 0.549
#
#    rate_of_interest  dtir1 lump_sum_payment
# 0             5.000     46             lpsm
# 1             4.689     30         not_lpsm
# 2             6.100     25             lpsm

# %%
# Predict the LKNN Untuned and KNN Tuned pipeline to the new_data
rand_result = random_for.predict(df)

# %%
df['label'] = rand_result
df
# Out:
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                    b/c
# 1           p2                l1        nopc                  nob/c
# 2           p4                l1        nopc                  nob/c
#
#    loan_amount  Upfront_charges credit_type  Interest_rate_spread  \
# 0       116450              590         EXP                 0.210
# 1       222309              263        EQUI                 0.124
# 2       432874              148        EQUI                 0.549
#
#    rate_of_interest  dtir1 lump_sum_payment  label
# 0             5.000     46             lpsm      0
# 1             4.689     30         not_lpsm      0
# 2             6.100     25             lpsm      0

# %% [markdown]
# **Model Inference Conclusion**
#
# Based on the predict result, the model shows the same result for those 3 dataframes (0 = Not Default)
